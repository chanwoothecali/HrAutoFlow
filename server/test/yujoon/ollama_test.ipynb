# %%
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# %%
# cmd // terminal에서 ollama serve 실행시켜야함

# Ollama 모델을 불러옵니다.
llm = ChatOllama(
    model="llama3",
    # format="json",  # 입출력 형식을 JSON으로 설정합니다.
    temperature=0,
)

# 프롬프트
prompt = ChatPromptTemplate.from_template("{topic} 에 대하여 간략히 설명해 줘.")

# 체인 생성
chain = prompt | llm | StrOutputParser()

# 간결성을 위해 응답은 터미널에 출력됩니다.
answer = chain.stream({"topic": "deep learning"})

# 스트리밍 출력
for chunk in chain.stream({"topic": "deep learning"}):
    print(chunk, end="", flush=True)
# Out:
# Here's a brief overview of deep learning:
#
# **What is Deep Learning?**
#
# Deep learning is a subfield of machine learning that involves the use of artificial neural networks to analyze and interpret data. These neural networks are composed of multiple layers, each of which processes and transforms the input data in some way.
#
# **Key Characteristics:**
#
# 1. **Hierarchical Representations**: Deep learning models learn to represent complex patterns in data by creating hierarchical representations, where early layers detect simple features and later layers combine these features to form more abstract representations.
# 2. **Multiple Layers**: Deep learning models typically consist of multiple layers, each with its own set of weights and biases. These layers are stacked on top of each other to create a deep neural network.
# 3. **Non-Linear Transformations**: Each layer applies non-linear transformations to the input data, allowing the model to learn complex relationships between inputs and outputs.
#
# **Types of Deep Learning Models:**
#
# 1. **Convolutional Neural Networks (CNNs)**: Designed for image and signal processing tasks, CNNs use convolutional and pooling layers to extract features.
# 2. **Recurrent Neural Networks (RNNs)**: Suitable for sequential data such as speech, text, or time series data, RNNs use recurrent connections to capture temporal dependencies.
# 3. **Autoencoders**: Used for dimensionality reduction, anomaly detection, and generative modeling, autoencoders learn to compress and reconstruct input data.
#
# **Applications of Deep Learning:**
#
# 1. **Computer Vision**: Image classification, object detection, segmentation, and generation.
# 2. **Natural Language Processing (NLP)**: Text classification, sentiment analysis, language translation, and text generation.
# 3. **Speech Recognition**: Speech-to-text systems that transcribe spoken audio into text.
# 4. **Game Playing**: Deep learning models have been used to play games like Go, Poker, and Video Games.
#
# **Challenges and Limitations:**
#
# 1. **Training Time**: Deep learning models can require significant computational resources and training time.
# 2. **Interpretability**: It can be difficult to understand the decision-making process of deep learning models.
# 3. **Overfitting**: Deep learning models are prone to overfitting, which occurs when a model becomes too specialized to the training data.
#
# **Conclusion:**
#
# Deep learning has revolutionized many fields by enabling machines to learn complex patterns and relationships in data. While it presents some challenges and limitations, deep learning continues to advance rapidly, with new applications and breakthroughs emerging regularly.
